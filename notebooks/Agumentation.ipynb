# %%
### Agumentation
#### From the Profiling it is evident that a lot of words are not present in the italian vocabolary
#### For this reason, and because the data is highly unbalanced, agumentation is needed to increase italian datapoints and
#### increase the words in its vocabolary

##### LOGIC
##### For each english text in the dataset: 
##### we translate the phrase and see its words
##### if the words are all present in the italian vocabolary, we do not insert it in the dataset
##### else, we insert the new phrase

##### The dataset holds 698 italian text and 9639 not italian


##### We will use GoogleTranlator api

from deep_translator import GoogleTranslator
import pandas as pd

# %%
dataset=pd.read_csv('..\\Dataset\\Lang_det_parsed.csv')   #the parsed dataset
words=pd.read_csv('..\\Dataset\\words.csv')     #csv holdeing all words in the dataset

# %%
#we retrive english text for now
english_text=dataset[dataset['Language']=='English']['Text']
english_text.shape
# Out:
# (1385,)

# %%
italian_words=set(words[words['where']==2]['Word'])
italian_words
# Out:
# {'&',
#  "'",
#  '-',
#  '-.',
#  '.',
#  '.la',
#  '[...]',
#  ']',
#  'a',
#  'abstract',
#  'academy',
#  'acceso',
#  'accurate',
#  'ad',
#  'agosto',
#  'ai',
#  'al',
#  'alan',
#  'algoritmo',
#  'alla',
#  'alle',
#  'alta',
#  'alto',
#  'america',
#  'amo',
#  'an',
#  'and',
#  'andrea',
#  'android.',
#  'anno',
#  'ars',
#  'arthur',
#  'assume',
#  'atroce',
#  'atroce.',
#  'aumento',
#  'austria',
#  'automaticamente',
#  'award',
#  'awards',
#  'bancario',
#  'barack',
#  'basa',
#  'base',
#  'bayesiana',
#  'bbc',
#  'bel',
#  'ben',
#  'biblioteca',
#  'bibliotecario',
#  'biografia',
#  'blue',
#  'bomis',
#  'bradley',
#  'brand',
#  'bravo',
#  'breiman',
#  'britannica',
#  'britannica.',
#  'brockhaus',
#  'buon',
#  'businessweek',
#  'by-sa',
#  "c't",
#  'c.',
#  'california',
#  'california.',
#  'campana',
#  'campo',
#  'canto',
#  'cara',
#  'carne',
#  'carta',
#  'casa',
#  'casa.',
#  'casi',
#  'caso',
#  'catch-',
#  'catch-.',
#  'categoria',
#  'categorie',
#  'causa',
#  'cd',
#  'ce',
#  'cell',
#  'cena',
#  'centrale',
#  'centro',
#  'ceo',
#  'certamente',
#  'certo',
#  'check',
#  'cielo',
#  'ciffolilli',
#  'cima',
#  'cinema',
#  'circa',
#  'cita',
#  'classe',
#  'clic',
#  'cluster',
#  'clustering',
#  'come',
#  'come.',
#  'commerciale',
#  'commons',
#  'commons.',
#  'community.',
#  'completamente',
#  'comportamento',
#  'comprensiva',
#  'computational',
#  'computer',
#  'computing',
#  'con',
#  'confuso',
#  'consenso',
#  'considera',
#  'consiste',
#  'consulta',
#  'contrario',
#  'controversia',
#  'cool.',
#  'copie',
#  'copyleft',
#  'copyright',
#  'copyright.',
#  'coronation',
#  'corse',
#  'corso',
#  'cosa',
#  'crea',
#  'creando',
#  'create',
#  'creative',
#  'critici',
#  'crossover',
#  'cultura',
#  'cunningham',
#  'curriculum',
#  'cyberarts',
#  'da',
#  'dale',
#  'data',
#  'data.',
#  'database',
#  'database.',
#  'dataset',
#  'dato',
#  'del',
#  'delhi',
#  'denota',
#  'dentro',
#  'dette',
#  'deve',
#  'devo',
#  'dia',
#  'dice',
#  'difficile',
#  'diffuse.',
#  'digitale',
#  'dilemma',
#  'dio',
#  'dire',
#  'dire.',
#  'disciplina',
#  'discipline',
#  'discovery.',
#  'dispositivo',
#  'dispute',
#  'disse',
#  'diverse',
#  'dna',
#  'do',
#  'dominio',
#  'donna',
#  'due',
#  'durante',
#  'dvd',
#  'dvd.',
#  'e',
#  'e.',
#  'economia',
#  'economist',
#  'edit',
#  'editor',
#  'eh',
#  'electronica',
#  'ellie',
#  'email',
#  'emigh',
#  'en.wikipedia.org',
#  'encarta',
#  'enciclopedia',
#  'enciclopedia.',
#  'enciclopedicamente',
#  'encyclopedia',
#  'enorme',
#  'epic',
#  'era',
#  'es.',
#  'essa',
#  'esse',
#  'esse.',
#  'everything',
#  'evitando',
#  'examples',
#  'extra',
#  'facile',
#  'facilmente',
#  'factor',
#  'fair',
#  'falso',
#  'famoso',
#  'farina',
#  'fase',
#  'feedback',
#  'festa',
#  'festival',
#  'figure',
#  'film',
#  'filosofia',
#  'fin',
#  'fine',
#  'fine.',
#  'fino',
#  'fluente',
#  'fluente.',
#  'flummox',
#  'fondo',
#  'fonte',
#  'forma',
#  'formalmente',
#  'formato',
#  'forte',
#  'fortemente',
#  'fortuna',
#  'fosse',
#  'foundation',
#  'foundation.',
#  'frances',
#  'francia',
#  'frank',
#  'frase',
#  'frase.',
#  'futura',
#  'futuro',
#  'generalmente',
#  'genere',
#  'geometria',
#  'geometry',
#  'gfdl',
#  'giro',
#  'globale',
#  'gmat',
#  'golden',
#  'google',
#  'grado',
#  'grammatica',
#  'gran',
#  'grande',
#  'gratuita',
#  'group',
#  'guardian',
#  'guerra',
#  'guide',
#  'ha',
#  'hard',
#  'hardware',
#  'hegel',
#  'heller',
#  'herring',
#  'hey',
#  'hg',
#  'ho',
#  'hoiberg',
#  'hopfield',
#  'i',
#  'i.',
#  'idea.',
#  'idee',
#  'identifica',
#  'il',
#  'ilp',
#  'impact',
#  'importa',
#  'importante',
#  'importasse.',
#  'importava',
#  'in',
#  'incomplete',
#  'indica',
#  'inductive',
#  'informatica',
#  'information',
#  'informativa',
#  'input',
#  'insulto',
#  'intelligence',
#  'intelligente',
#  'interessante',
#  'interesse',
#  'international',
#  'interne',
#  'internet',
#  'internet.',
#  'interno',
#  'interrompendo',
#  'inutile',
#  'iphone',
#  'italiana',
#  'italiano',
#  'jimmy',
#  'john',
#  'jordan',
#  'joseph',
#  'knowledge-based',
#  "l'enciclopedia",
#  "l'origine",
#  'la',
#  'largo',
#  'larry',
#  'latina',
#  'latine',
#  'le',
#  'learning',
#  'lei',
#  'lenta',
#  'lentamente',
#  'lento',
#  'lento.',
#  'leo',
#  'li',
#  'libre',
#  'libre.',
#  'libro',
#  'light',
#  'line',
#  'link',
#  'linus',
#  'liste',
#  'lo',
#  'logic',
#  'logo',
#  'lucro',
#  'lui',
#  'lui.',
#  'là',
#  'm.',
#  'ma',
#  'machine',
#  'machinery',
#  'madre',
#  'magazine',
#  'mai',
#  'male',
#  'mamma',
#  'mano',
#  'mantiene',
#  'marian',
#  'marian.',
#  'marion',
#  'marion.',
#  'marketing',
#  'markov',
#  'markup',
#  'marzo',
#  'mass',
#  'massa',
#  'materiale',
#  'matrimonio',
#  'matrimonio.',
#  'mchenry',
#  'me',
#  'me.',
#  'media',
#  'mediawiki',
#  'mediawiki.',
#  'medio',
#  'melissa',
#  'melli',
#  'mellie',
#  'mentalmente',
#  'mente',
#  'messenger',
#  'mi',
#  'michael',
#  'microsoft',
#  'mille',
#  'mining',
#  'ministro',
#  'minuto',
#  'mio.',
#  'mirror',
#  'mitchell',
#  'mobile',
#  'modo',
#  'momento',
#  'momento.',
#  'mondiale',
#  'mondiale.',
#  'motivo',
#  'multilingue',
#  nan,
#  'narcis',
#  'narcisa',
#  'narcisa.',
#  'narcisismo',
#  'narciso',
#  'narciso.',
#  'narcissa.',
#  'narcisse',
#  'national',
#  'natura',
#  'nature',
#  'ne',
#  'necessariamente',
#  'negativo',
#  'news',
#  'nica',
#  'no',
#  'no.',
#  'nome',
#  'non',
#  'norma',
#  'normalmente',
#  'nota',
#  'note',
#  'novembre',
#  'nupedia',
#  'né',
#  'o',
#  'o.',
#  'obama',
#  'occupa',
#  'of',
#  'offline',
#  'offre',
#  'oh',
#  'oh.',
#  'ok',
#  'on',
#  'online',
#  'open',
#  'opera',
#  'origine',
#  'oro',
#  'output',
#  'overfitting',
#  'oxford',
#  'p',
#  'padre',
#  'pae',
#  'pagina',
#  'paideia',
#  'paradigma',
#  'parlamento',
#  'parole',
#  'parte',
#  'passo',
#  'password',
#  'pattern',
#  'pedia',
#  'pena',
#  'pena.',
#  'penso',
#  'per',
#  'perceptrons',
#  'performance',
#  'permanente',
#  'persona',
#  'persona.',
#  'personalmente',
#  'philip',
#  'pizza',
#  'poco',
#  'positivo',
#  'possa',
#  'posso',
#  'posso.',
#  'precisa',
#  'preciso',
#  'premio',
#  'preprocessing',
#  'presente',
#  'preso',
#  'primaria',
#  'principalmente',
#  'principe',
#  'principio',
#  'prix',
#  'problema',
#  'problema.',
#  'proceedings',
#  'processo',
#  'programma',
#  'programming',
#  'progress',
#  'pronto',
#  'pronuncia',
#  'propose',
#  'proposta.',
#  'protein',
#  'prova',
#  'prove',
#  'proviene',
#  'publishing',
#  'punto',
#  'qual',
#  'quando',
#  'quanto',
#  'quel',
#  'quelle',
#  'qui',
#  'raramente',
#  'realmente',
#  'records',
#  'regalo',
#  'relativamente',
#  'rende',
#  'rendezvous',
#  'rendezvous.',
#  'repository',
#  'resa',
#  'retrieval.',
#  'robert',
#  'robot',
#  'rock',
#  'routine',
#  'rumelhart',
#  'russo',
#  'sa',
#  'sai',
#  'sala',
#  'salto',
#  'samuel',
#  'sanger',
#  'sapere',
#  'school',
#  'science',
#  'science.',
#  'sciences',
#  'se',
#  'se.',
#  'sei',
#  'sei.',
#  'seigenthaler',
#  'sempre',
#  'senso',
#  'september',
#  'seria',
#  'serio',
#  'server',
#  'si',
#  'siciliano',
#  'siete',
#  'significa',
#  'significa.',
#  'significativa',
#  'significativo',
#  'sistema',
#  'sistemi',
#  'smartphone',
#  'sms',
#  'so',
#  'so.',
#  'sociale',
#  'software',
#  'solamente',
#  'solo',
#  'sono',
#  'sorprende',
#  'source',
#  'spam',
#  'speciale',
#  'stanford',
#  'state',
#  'street',
#  'su',
#  'sua',
#  'suave',
#  'sue',
#  'super',
#  'superando',
#  'support',
#  'survey',
#  'susning.nu',
#  'svm',
#  'systems',
#  'sé',
#  't',
#  'tale',
#  'tanto',
#  'te',
#  'tecnologia',
#  'ted',
#  'temo',
#  'tempo',
#  'tende',
#  'terabyte',
#  'terrence',
#  'terry',
#  'test',
#  'the',
#  'thomas',
#  'ti',
#  'time',
#  'tipo',
#  'to',
#  'today',
#  'toefl',
#  'tom',
#  'tono',
#  'tony',
#  'totalmente.',
#  'training',
#  'tre',
#  'tremendamente',
#  'trimestre',
#  'triste',
#  'tu',
#  'tu.',
#  'tue',
#  'turing',
#  'turista',
#  'ultime',
#  'umm.',
#  'un',
#  'una',
#  'universalmente',
#  'university',
#  'uno',
#  'usa',
#  'usando',
#  'usarlo',
#  'use',
#  'user',
#  'uso',
#  'uso.',
#  'utile',
#  'va',
#  'va.',
#  'vai',
#  'vale',
#  'vandalismo',
#  'vandalismo.',
#  'varie',
#  'vector',
#  'venir',
#  'verbale',
#  'verbo',
#  'vi',
#  'via',
#  'video',
#  'video.',
#  'vista',
#  'visto',
#  'visto.',
#  'visualeditor.',
#  'vocale',
#  'w',
#  'wales',
#  'war',
#  'ward',
#  'web',
#  'webby',
#  'weekend',
#  'whatsapp',
#  'white',
#  'wiki',
#  'wikibooks',
#  'wikimedia',
#  'wikinfo',
#  'wikipedia',
#  'wikipedia.',
#  'wikipedia.com',
#  'wikipedia.org',
#  'wikiquote',
#  'wikireader',
#  'wikisource',
#  'wikispecies',
#  'wiktionary',
#  'william',
#  'wired',
#  'work',
#  'world',
#  'www',
#  'xx',
#  'yongle',
#  'you',
#  'youtube.',
#  'zona',
#  '\xa0',
#  '«una',
#  '«wikipedia',
#  'παιδεία',
#  '–'}

# %%
#For each phrase in eng, we translate it and then see if there is a new word using bloom filter
#pip install bloomfilter-py
from bloomfilter import BloomFilter
bloom_filter = BloomFilter(expected_insertions=len(italian_words)*2, err_rate=0.01)

# %%
#translation method

def translate_text(text, tranlator):
    out=tranlator.translate(text)
    return out

# %%
#filtering method
#if the word is not in the bloom filter,
#we return true and add it to the bloom filter
def handle_text(word,bloom_filter):
    if word not in bloom_filter:
        bloom_filter.put(word)
    return True

# %%
#splitting the english text
def split_text(text):
    return text.split(' ')

# %%
english_text=list(english_text)
tranlator=GoogleTranslator(source='en',target='it')
new_text=[]
for text in english_text:
    translated=translate_text(text,tranlator)
    words=split_text(translated)
    for w in words:
        if handle_text(w,bloom_filter):
            new_text.append(translated)
            break

print(len(new_text))
# Out:
# 1385

# %%
#inserting the new italian text in the dataset
to_insert=[]
for text in new_text:
    number_of_words=len(text.split(' '))
    number_of_spaces=number_of_words-1
    label=1
    lang='Italian'
    entry=[text,lang,label,number_of_words,number_of_spaces]
    to_insert.append(entry)

columns=dataset.columns.to_list()[1:]
columns
# Out:
# ['Text', 'Language', 'Class', 'Number of words', 'Number of spaces']

# %%
new_dataset=pd.DataFrame(data=to_insert,columns=columns)
new_dataset=pd.concat([dataset,new_dataset],ignore_index=True,axis=0)

# %%
#after agumetation the italian entrys are the following
italian_entry_numb=new_dataset[new_dataset.Class == 1].shape[0]
italian_entry_numb
# Out:
# 2083

# %%
italian_entry=new_dataset[new_dataset.Class==1]
italian_entry
# Out:
#        Unnamed: 0                                               Text Language  \
# 7114       7114.0  nature è una delle più antiche ed importanti r...  Italian
# 7115       7115.0               viene pubblicata fin dal  novembre .  Italian
# 7116       7116.0  nonostante la maggior parte delle riviste del ...  Italian
# 7117       7117.0  molti sono gli avanzamenti e le scoperte prove...  Italian
# 7118       7118.0  il fattore di impatto impact factor di questa ...  Italian
# ...           ...                                                ...      ...
# 11717         NaN  qual è stato il tuo errore vieni ti diamo da m...  Italian
# 11718         NaN  narcisa ha cambiato i suoi modi, all'inizio ha...  Italian
# 11719         NaN  com'è il narcisismo ora Marian ha detto a entr...  Italian
# 11720         NaN  ha lei immagino che non vorrebbe più pane d'or...  Italian
# 11721         NaN  terry in realtà assomigli un po' a quell'angel...  Italian
#
#        Class  Number of words  Number of spaces
# 7114       1               27                26
# 7115       1                7                 6
# 7116       1               41                40
# 7117       1               82                81
# 7118       1               16                15
# ...      ...              ...               ...
# 11717      1               19                18
# 11718      1               40                39
# 11719      1               22                21
# 11720      1               13                12
# 11721      1               21                20
#
# [2083 rows x 6 columns]

# %%
#saving the new dataset
new_dataset.to_csv('..\\Dataset\\Dataset_agumented1.csv')
